# %%
from pyspark.sql.functions import * 
from pyspark.sql.types import *

# %% [markdown]
# # SILVER LAYER SCRIPT

# %% [markdown]
# ### DATA ACCESS USING APP

# %%
spark.conf.set("fs.azure.account.auth.type.rawdatastoreabdul.dfs.core.windows.net", "OAuth")
spark.conf.set("fs.azure.account.oauth.provider.type.rawdatastoreabdul.dfs.core.windows.net", "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider")
spark.conf.set("fs.azure.account.oauth2.client.id.rawdatastoreabdul.dfs.core.windows.net", "b5543c88-beca-4e93-ba19-c6d2d77fdb2a")
spark.conf.set("fs.azure.account.oauth2.client.secret.rawdatastoreabdul.dfs.core.windows.net", "6wY8Q~-x8M.Grk3v61bXhbt5APfiZvWpcN5G4a6K")
spark.conf.set("fs.azure.account.oauth2.client.endpoint.rawdatastoreabdul.dfs.core.windows.net", "https://login.microsoftonline.com/02bebf42-d5f0-4451-becd-adb25ee36dcb/oauth2/token")

# %% [markdown]
# ### DATA LOADING

# %% [markdown]
# #### Reading Data

# %%
df_cal = spark.read.format('csv').option("header", True).option("InferSchema", True).load('abfss://bronze@rawdatastoreabdul.dfs.core.windows.net/AdventureWorks_Calendar')

# %%
df_cus = spark.read.format('csv').option("header", True).option("InferSchema", True).load('abfss://bronze@rawdatastoreabdul.dfs.core.windows.net/AdventureWorks_Customers')

# %%
df_prodcat = spark.read.format('csv').option("header", True).option("InferSchema", True).load('abfss://bronze@rawdatastoreabdul.dfs.core.windows.net/AdventureWorks_Product_Categories')

# %%
df_prodsubcat = spark.read.format('csv').option("header", True).option("InferSchema", True).load('abfss://bronze@rawdatastoreabdul.dfs.core.windows.net/AdventureWorks_Product_Subcategories')

# %%
df_prod = spark.read.format('csv').option("header", True).option("InferSchema", True).load('abfss://bronze@rawdatastoreabdul.dfs.core.windows.net/AdventureWorks_Products')

# %%
df_ret = spark.read.format('csv').option("header", True).option("InferSchema", True).load('abfss://bronze@rawdatastoreabdul.dfs.core.windows.net/AdventureWorks_Returns')

# %%
df_sales = spark.read.format('csv').option("header", True).option("InferSchema", True).load('abfss://bronze@rawdatastoreabdul.dfs.core.windows.net/AdventureWorks_Sales*')

# %%
df_Tert = spark.read.format('csv').option("header", True).option("InferSchema", True).load('abfss://bronze@rawdatastoreabdul.dfs.core.windows.net/AdventureWorks_Territories')

# %% [markdown]
# ### TRANSFORMATIONS

# %%
df_cal.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.withColumn("Month", month(col("Date")))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-6978636542107565>, line 1
# ----> 1 df_cal = df.withColumn("Month", month(col("Date")))
#
# NameError: name 'df' is not defined
